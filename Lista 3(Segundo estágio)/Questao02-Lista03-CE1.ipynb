# %%
import sympy as sp
import numpy as np
from sympy import *
from utils import symdisp, symplot, round_expr

# %%
m =[8,1,4]#>>>>>>> OS 3 ULTIMO DÍGITOS DA MATRÍCULA <<<<<<<<<<<<<
x = m[0]+1
y = m[1]+1
z = m[2]+1

# %%
t = sp.symbols('t', real=True)
C = 500*10**-6
L = 100*10**-3
v_C_inicial = -x
i_L_inicial = 0.1*y
i = 500*sp.exp(-z*t)*cos(20*t)*(10**-3)
v1 = -2*sp.exp(-y*t)
v2 = 5*t*sp.exp(-x*t)
symdisp('C = ',C*10**6,'uF')
symdisp('L = ',L*10**3,'mH')
symdisp('v_C (0) = ',v_C_inicial,'V')
symdisp('i_L (0) = ',i_L_inicial,'A')
symdisp('i(t) = i_C(t) = ',i*10**3,'mA')
symdisp('v_1(t) = ',v1,'V')
symdisp('v_2(t) = ',v2,'V')
# Out:
# $\displaystyle C = 500.0\;uF$
# $\displaystyle L = 100.0\;mH$
# $\displaystyle v_C (0) = -9\;V$
# $\displaystyle i_L (0) = 0.2\;A$
# $\displaystyle i(t) = i_C(t) = 500.0 e^{- 5 t} \cos{\left(20 t \right)}\;mA$
# $\displaystyle v_1(t) = - 2 e^{- 2 t}\;V$
# $\displaystyle v_2(t) = 5 t e^{- 9 t}\;V$

# %% [markdown]
# # Letra A

# %%
#Tensão no Capacitor
v_C_t = (C**-1)*sp.integrate(i,(t,0,t))+v_C_inicial
symdisp('v_C(t) = ',round_expr(v_C_t,3),'V')

#Tensão no Indutor
diff_i_beta = ((v1+v2)/L) + sp.diff(i,t)
diff_i_L_t  =  diff_i_beta - sp.diff(i,t)
v_L_t = L*diff_i_L_t
symdisp('v_L(t) = ',round_expr(v_L_t,3),'V')
# Out:
# $\displaystyle v_C(t) = 2.765 + 47.059 e^{- 5 t} \sin{\left(20 t \right)} - 11.765 e^{- 5 t} \cos{\left(20 t \right)}\;V$
# $\displaystyle v_L(t) = 5.0 t e^{- 9 t} - 2.0 e^{- 2 t}\;V$

# %%
#tensões
intervalo = np.arange(0,3,0.005)
symplot(t,[v_C_t,v_L_t],intervalo,['Tensão no capacitor','Tensão no indutor'])

# %% [markdown]
# Verificamos que NÃO É POSSÍVEL VARIAÇÃO ABRUPTA DE TENSÃO NO CAPACITOR

# %%
#corrente no Capacitor e no Indutor
i_L_t = sp.integrate(v_L_t,(t,0,t))+i_L_inicial
intervalo = np.arange(0,3,0.005)
symplot(t,[i,i_L_t],intervalo,['Corrente no Capacitor','Corrente no Indutor'])

# %% [markdown]
# Verificação de que NÃO HÁ VARIAÇÃO ABRUPTA DE CORRENTE NO INDUTOR

# %% [markdown]
# # Letra B

# %%
#Potência na fonte de corrente
v_i = v_L_t - v1 - v_C_t
p_i = v_i*i
symdisp('P_{i(t)}(t) = ',round_expr(p_i.simplify(),3),'W')
intervalo = np.arange(0,1,0.005)
symplot(t,p_i,intervalo,'Potência na fonte de corrente')
# Out:
# $\displaystyle P_{i(t)}(t) = 0.5 \left(5.0 t + \left(- 47.059 \sin{\left(20 t \right)} + 11.765 \cos{\left(20 t \right)}\right) e^{4 t} - 2.765 e^{9 t}\right) e^{- 14 t} \cos{\left(20 t \right)}\;W$

# %% [markdown]
# # Letra C

# %%
#Corrente em V1 é i_L_t
#Corrente em V2 é i_L_t + i_C_t, i_C_t == i
#Logo a potência nas fontes serão:
p_v1 = v1*i_L_t
symdisp('P_{v_1(t)}(t) =',round_expr(p_v1.simplify(),3),'W')

p_v2 = v2*(i+i_L_t)
symdisp('P_{v_2(t)}(t) =',round_expr(p_v2.simplify(),3),'W')


intervalo = np.arange(0,3,0.005)
symplot(t,[p_v1,p_v2],intervalo,['Potência na fonte de Tensão V1','Potência na fonte de Tensão V2'])
# Out:
# $\displaystyle P_{v_1(t)}(t) =\left(1.111 t + 1.477 e^{9 t} - 2.0 e^{7 t} + 0.123\right) e^{- 11 t}\;W$
# $\displaystyle P_{v_2(t)}(t) =1.0 t \left(- 2.778 t - 3.691 e^{9 t} + 5.0 e^{7 t} + 2.5 e^{4 t} \cos{\left(20 t \right)} - 0.309\right) e^{- 18 t}\;W$

# %% [markdown]
# # Letra D

# %%
# C = q/v_C_t
q = C*v_C_t
q_oo = sp.limit(q,t,oo)
print('Carga total armazenada no capacitor em t -> oo')
symdisp('lim_{t->+oo} q(t) =',round(q_oo*10**3,3),'mC')
# Out:
# Carga total armazenada no capacitor em t -> oo
# $\displaystyle lim_{t->+oo} q(t) =1.382\;mC$

# %% [markdown]
# # Letra E

# %%
W_C = (1/2)*C*(v_C_t**2)
W_C_oo = sp.limit(W_C,t,oo)
print('Energia acumulada no capacitor em t -> oo')
symdisp('lim_{t->+oo} W_C(t) =',round(W_C_oo*10**3,3),'mJ')

W_L = (1/2)*L*(i_L_t**2)
W_L_oo = sp.limit(W_L,t,oo)
print('Energia acumulada no Indutor em t -> oo')
symdisp('lim_{t->+oo} W_L(t) =',round(W_L_oo*10**3,3),'mJ')
# Out:
# Energia acumulada no capacitor em t -> oo
# $\displaystyle lim_{t->+oo} W_C(t) =1.911\;mJ$
# Energia acumulada no Indutor em t -> oo
# $\displaystyle lim_{t->+oo} W_L(t) =27.252\;mJ$

# %% [markdown]
# # Letra F

# %%
print('Tensão e Corrente no Capacitor em t-> oo')
v_C_t_oo = sp.limit(v_C_t,t,oo)
i_oo = sp.limit(i,t,oo)
symdisp('lim_{t->+oo} V_C(t) =',round(v_C_t_oo,3),'V')
symdisp('lim_{t->+oo} i_C(t) =',round(i_oo,3),'A')

print('\nTensão e corrente no Indutor em t-> oo')
v_L_t_oo = sp.limit(v_L_t,t,oo)
i_L_t_oo = sp.limit(i_L_t,t,oo)
symdisp('lim_{t->+oo} V_L(t) =',round(v_L_t_oo,3),'V')
symdisp('lim_{t->+oo} i_L(t) =',round(i_L_t_oo,3),'A')
# Out:
# Tensão e Corrente no Capacitor em t-> oo
# $\displaystyle lim_{t->+oo} V_C(t) =2.765\;V$
# $\displaystyle lim_{t->+oo} i_C(t) =0\;A$
# Tensão e corrente no Indutor em t-> oo
# $\displaystyle lim_{t->+oo} V_L(t) =0\;V$
# $\displaystyle lim_{t->+oo} i_L(t) =-0.738\;A$
